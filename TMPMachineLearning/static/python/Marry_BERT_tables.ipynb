# %%
# Bring in all dependencies
import pandas as pd
import requests
import numpy as np
import scipy as sp
from statistics import mode
from babel.numbers import format_number, format_decimal, format_percent, format_currency, decimal
from decimal import localcontext, Context, ROUND_UP

# %%
########## Read in BERT clusters & user table files ##########
BERT_path = '../resources/BERT_clusters.csv'
BERT = pd.read_csv(BERT_path,index_col = False)

USER_path = '../resources/user_table.csv'
USER = pd.read_csv(USER_path,index_col = False)

# %%
########## Combine dfs to align clusters to user info ##########
Final_table = USER.merge(BERT, left_on='Ticker', right_on='Symbol')

########## Keep only the columns needed for FLASK ##########
Final_table = Final_table[['Ticker','Company', 'Industry','Price','Dividends','ROI','Risk','Clusters']]
Final_table
# Out:
#     Ticker                                            Company  \
# 0      JEF        Jefferies Financial Group Inc. Common Stock
# 1     MTOR                          Meritor Inc. Common Stock
# 2      MSC  Studio City International Holdings Limited Ame...
# 3      CHE                                        Chemed Corp
# 4      KRC             Kilroy Realty Corporation Common Stock
# ..     ...                                                ...
# 469    BOH            Bank of Hawaii Corporation Common Stock
# 470    CMA                 Comerica Incorporated Common Stock
# 471    NYT          New York Times Company (The) Common Stock
# 472    FIX              Comfort Systems USA Inc. Common Stock
# 473    WTI                     W&T Offshore Inc. Common Stock
#
#                    Industry      Price Dividends ROI      Risk  Clusters
# 0        Financial Services   $32.2900   $0.0000  0%  Low Risk         2
# 1         Consumer Cyclical   $26.7100   $0.0000  0%  Low Risk         1
# 2         Consumer Cyclical   $11.0540   $0.0000  0%  Low Risk         3
# 3                Healthcare  $489.7000   $0.0000  0%  Low Risk         0
# 4               Real Estate   $72.5600   $0.0000  0%  Low Risk         0
# ..                      ...        ...       ...  ..       ...       ...
# 469      Financial Services   $89.7500   $0.0000  0%  Low Risk         8
# 470      Financial Services   $79.0100   $0.0000  0%  Low Risk         4
# 471  Communication Services   $43.1500   $0.0000  0%  Low Risk         3
# 472             Industrials   $84.5300   $0.0000  0%  Low Risk         1
# 473                  Energy    $4.0700   $0.0000  0%  Low Risk         1
#
# [474 rows x 8 columns]

# %%
########## send to CSV for FLASK routes ##########
Final_table.to_csv('../resources/BERTs_Flask_table.csv')
